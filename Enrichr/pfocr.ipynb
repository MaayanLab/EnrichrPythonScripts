# %%
import requests
import json
import re
from tqdm import tqdm
import os
import pandas as pd
import time
import math
from glob import glob
import uuid

import pyarrow.feather as feather
from tqdm import tqdm
from scipy.stats import rankdata, zscore
import csv

# %% [markdown]
# ## Human

# %%
sn = "Homo_sapiens"
organism = "../Serialization/Mammalia/%s"%sn
url = 'ftp://ftp.ncbi.nih.gov/gene/DATA/GENE_INFO/{}.gene_info.gz'.format(organism)
file = '{}.gene_info.tsv'.format(organism)

# %%
def fetch_save_read(url, file, reader=pd.read_csv, sep='\t', **kwargs):
  ''' Download file from {url}, save it to {file}, and subsequently read it with {reader} using pandas options on {**kwargs}.
  '''
  if not os.path.exists(file):
    if os.path.dirname(file):
      os.makedirs(os.path.dirname(file), exist_ok=True)
    df = reader(url, sep=sep, index_col=None)
    df.to_csv(file, sep=sep, index=False)
  return pd.read_csv(file, sep=sep, **kwargs)

# %%
ncbi_gene = fetch_save_read(url, file)
ncbi_gene = ncbi_gene.set_index("GeneID")
ncbi_gene.head()
# Out:
#         #tax_id Symbol LocusTag                   Synonyms  \
# GeneID
# 1          9606   A1BG        -       A1B|ABG|GAB|HYST2477
# 2          9606    A2M        -  A2MD|CPAMD5|FWP007|S863-7
# 3          9606  A2MP1        -                       A2MP
# 9          9606   NAT1        -       AAC1|MNAT|NAT-1|NATI
# 10         9606   NAT2        -            AAC2|NAT-2|PNAT
#
#                                                   dbXrefs chromosome  \
# GeneID
# 1       MIM:138670|HGNC:HGNC:5|Ensembl:ENSG00000121410...         19
# 2       MIM:103950|HGNC:HGNC:7|Ensembl:ENSG00000175899...         12
# 3       HGNC:HGNC:8|Ensembl:ENSG00000291190|AllianceGe...         12
# 9       MIM:108345|HGNC:HGNC:7645|Ensembl:ENSG00000171...          8
# 10      MIM:612182|HGNC:HGNC:7646|Ensembl:ENSG00000156...          8
#
#        map_location                         description    type_of_gene  \
# GeneID
# 1          19q13.43              alpha-1-B glycoprotein  protein-coding
# 2          12p13.31               alpha-2-macroglobulin  protein-coding
# 3          12p13.31  alpha-2-macroglobulin pseudogene 1          pseudo
# 9              8p22               N-acetyltransferase 1  protein-coding
# 10             8p22               N-acetyltransferase 2  protein-coding
#
#        Symbol_from_nomenclature_authority  \
# GeneID
# 1                                    A1BG
# 2                                     A2M
# 3                                   A2MP1
# 9                                    NAT1
# 10                                   NAT2
#
#        Full_name_from_nomenclature_authority Nomenclature_status  \
# GeneID
# 1                     alpha-1-B glycoprotein                   O
# 2                      alpha-2-macroglobulin                   O
# 3         alpha-2-macroglobulin pseudogene 1                   O
# 9                      N-acetyltransferase 1                   O
# 10                     N-acetyltransferase 2                   O
#
#                                        Other_designations  Modification_date  \
# GeneID
# 1       alpha-1B-glycoprotein|HEL-S-163pA|epididymis s...           20220805
# 2       alpha-2-macroglobulin|C3 and PZP-like alpha-2-...           20221009
# 3                       pregnancy-zone protein pseudogene           20221025
# 9       arylamine N-acetyltransferase 1|N-acetyltransf...           20220925
# 10      arylamine N-acetyltransferase 2|N-acetyltransf...           20221009
#
#        Feature_type
# GeneID
# 1                 -
# 2                 -
# 3                 -
# 9                 -
# 10                -

# %%
missing = set()
removed = {}
human_ids = set()
merged_gmt = {}
with open("data/PFOCR_Pathways_Human_2023.gmt") as f:
    with open("output/PFOCR_Pathways_Human_2023.gmt", "w") as o:
        csv_writer = csv.writer(o, delimiter="\t")
        for line in f:
            label, description, *genes = line.strip().split("\t")
            row = [label, description]
            for i in genes:
                gene_id = int(i)
                if gene_id in ncbi_gene.index:
                    gene = ncbi_gene.at[gene_id, "Symbol"]
                    row.append(gene)
                else:
                    missing.add(gene_id)
            if len(row) >= 7: # use only gene sets with at least 5 genes:
                human_ids.add(label)
                csv_writer.writerow(row)
                merged_gmt[label] = set(row[2:])
            else:
                removed[label] = len(row) - 2
len(missing), len(removed)
# Out:
# (6, 13770)

# %% [markdown]
# ## Mouse

# %%
sn = "Mus_musculus"
organism = "../Serialization/Mammalia/%s"%sn
url = 'ftp://ftp.ncbi.nih.gov/gene/DATA/GENE_INFO/{}.gene_info.gz'.format(organism.replace("../Serialization/", ""))
file = '{}.gene_info.tsv'.format(organism)

# %%
ncbi_gene = fetch_save_read(url, file)
ncbi_gene = ncbi_gene.set_index("GeneID")
ncbi_gene.head()
# Out:
#         #tax_id Symbol LocusTag                      Synonyms  \
# GeneID
# 11287     10090    Pzp        -                   A1m|A2m|MAM
# 11298     10090  Aanat        -        AA-NAT|Nat-2|Nat4|Snat
# 11302     10090   Aatk        -        AATYK|aatyk1|mKIAA0641
# 11303     10090  Abca1        -                    ABC-1|Abc1
# 11304     10090  Abca4        -  Abc10|Abcr|D430003I15Rik|RmP
#
#                                                   dbXrefs chromosome  \
# GeneID
# 11287   MGI:MGI:87854|Ensembl:ENSMUSG00000030359|Allia...          6
# 11298   MGI:MGI:1328365|Ensembl:ENSMUSG00000020804|All...         11
# 11302   MGI:MGI:1197518|Ensembl:ENSMUSG00000025375|All...         11
# 11303   MGI:MGI:99607|Ensembl:ENSMUSG00000015243|Allia...          4
# 11304   MGI:MGI:109424|Ensembl:ENSMUSG00000028125|Alli...          3
#
#              map_location                                        description  \
# GeneID
# 11287     6 F3|6 63.02 cM                    PZP, alpha-2-macroglobulin like
# 11298   11 81.43 cM|11 E2                 arylalkylamine N-acetyltransferase
# 11302            11|11 E2               apoptosis-associated tyrosine kinase
# 11303     4 B2|4 28.57 cM  ATP-binding cassette, sub-family A (ABC1), mem...
# 11304     3 G1|3 52.94 cM  ATP-binding cassette, sub-family A (ABC1), mem...
#
#           type_of_gene Symbol_from_nomenclature_authority  \
# GeneID
# 11287   protein-coding                                Pzp
# 11298   protein-coding                              Aanat
# 11302   protein-coding                               Aatk
# 11303   protein-coding                              Abca1
# 11304   protein-coding                              Abca4
#
#                     Full_name_from_nomenclature_authority Nomenclature_status  \
# GeneID
# 11287                     PZP, alpha-2-macroglobulin like                   O
# 11298                  arylalkylamine N-acetyltransferase                   O
# 11302                apoptosis-associated tyrosine kinase                   O
# 11303   ATP-binding cassette, sub-family A (ABC1), mem...                   O
# 11304   ATP-binding cassette, sub-family A (ABC1), mem...                   O
#
#                                        Other_designations  Modification_date  \
# GeneID
# 11287   pregnancy zone protein|alpha 1 macroglobulin|a...           20230412
# 11298   serotonin N-acetyltransferase|aralkylamine N-a...           20230518
# 11302   serine/threonine-protein kinase LMTK1|apoptosi...           20230412
# 11303   phospholipid-transporting ATPase ABCA1|ATP-bin...           20230518
# 11304   retinal-specific phospholipid-transporting ATP...           20230412
#
#        Feature_type
# GeneID
# 11287             -
# 11298             -
# 11302             -
# 11303             -
# 11304             -

# %%
missing = set()
removed = {}
mouse_ids = set()
with open("data/PFOCR_Pathways_Mouse_2023.gmt") as f:
    with open("output/PFOCR_Pathways_Mouse_2023.gmt", "w") as o:
        csv_writer = csv.writer(o, delimiter="\t")
        for line in f:
            label, description, *genes = line.strip().split("\t")
            row = [label, description]
            for i in genes:
                gene_id = int(i)
                if gene_id in ncbi_gene.index:
                    gene = ncbi_gene.at[gene_id, "Symbol"]
                    row.append(gene.upper())
                else:
                    missing.add(gene_id)
            if len(row) >= 7: # use only gene sets with at least 5 genes:
                mouse_ids.add(label)
                csv_writer.writerow(row)
                if label not in merged_gmt:
                    merged_gmt[label] = set(row[2:])
                else:
                    merged_gmt[label] = merged_gmt[label].union(row[2:])
            else:
                removed[label] = len(row) - 2
len(missing), len(removed)
# Out:
# (21, 13468)

# %%
len(human_ids), len(mouse_ids), len(merged_gmt)
# Out:
# (21694, 21359, 21845)

# %%
with open("output/PFOCR_Pathways_2023.gmt", "w") as o:
    csv_writer = csv.writer(o, delimiter="\t")
    for k,v in merged_gmt.items():
        row = [k, ''] + list(v)
        csv_writer.writerow(row)
