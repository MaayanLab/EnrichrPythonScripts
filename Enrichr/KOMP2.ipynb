# %%
import pandas as pd

# %%
df = pd.read_csv("data/genotype-phenotype-assertions-ALL.csv")
df.head()
# Out:
#   marker_accession_id marker_symbol phenotyping_center         colony_id  \
# 0         MGI:1354962         Copb2                BCM             COPBB
# 1         MGI:1926194         Tnip1        MRC Harwell  H-TNIP1-F09-TM1B
# 2          MGI:106417         Cherp                JAX           JR32021
# 3         MGI:1929209        Cldn18           UC Davis            ET9093
# 4         MGI:1354170         Cbarp                BCM             CBRPB
#
#               sex      zygosity allele_accession_id  \
# 0            male  heterozygote         MGI:6257733
# 1            male    homozygote         MGI:6195689
# 2  not_considered    homozygote         MGI:6151421
# 3          female    homozygote         MGI:5569064
# 4  not_considered    homozygote         MGI:6324149
#
#                allele_symbol  \
# 0        Copb2<em1(IMPC)Bay>
# 1    Tnip1<tm1b(EUCOMM)Hmgu>
# 2          Cherp<em1(IMPC)J>
# 3    Cldn18<tm1.1(KOMP)Vlcg>
# 4  Cbarp<tm2e.1(EUCOMM)Hmgu>
#
# ...

# %%
gmt = {}
genes = set()
for i in df.iterrows():
    data = i[1]
    mp_term_name = data['mp_term_name']
    mp_term_id = data['mp_term_id']
    label = "%s (%s)\t"%(mp_term_name, mp_term_id)
    if label not in gmt:
        gmt[label] = set()
    
    gene = data['marker_symbol']
    gene = gene.upper()
    genes.add(gene)
    gmt[label].add(gene)

print("Terms: %s"%len(gmt))

print("Gene Coverage: %s"%len(genes))
gene_counts = 0
max_genes = 0
min_genes = 100
for i in gmt.values():
    gene_counts += len(i)
    if len(i) > max_genes:
        max_genes = len(i)
    if len(i) < min_genes:
        min_genes = len(i)

print("Average genes per terms: %s"%(gene_counts/len(gmt)))
print("Max genes per terms: %s"%(max_genes))
print("Min genes per terms: %s"%(min_genes))
# Out:
# Terms: 827
# Gene Coverage: 7314
# Average genes per terms: 46.89117291414752
# Max genes per terms: 1868
# Min genes per terms: 1

# %%
with open("/Users/maayanlab/Documents/codebase/enrichr_utils/gmt/KOMP2.gmt", "w") as o:
    for k,v in gmt.items():
        line = [k] + list(v) + ["\n"]
        o.write("\t".join(line))
