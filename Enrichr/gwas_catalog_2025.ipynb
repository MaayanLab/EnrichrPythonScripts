# %%
import pandas as pd
import requests
import json
import re
from tqdm import tqdm
import os
import pandas as pd
import time
import math
from glob import glob
import uuid

import pyarrow.feather as feather
from tqdm import tqdm
from scipy.stats import rankdata, zscore

# %%
sn = "Homo_sapiens"
organism = "../Serialization/Mammalia/%s"%sn
url = 'ftp://ftp.ncbi.nih.gov/gene/DATA/GENE_INFO/{}.gene_info.gz'.format(organism)
file = '{}.gene_info.tsv'.format(organism)

# %%
def fetch_save_read(url, file, reader=pd.read_csv, sep='\t', **kwargs):
  ''' Download file from {url}, save it to {file}, and subsequently read it with {reader} using pandas options on {**kwargs}.
  '''
  if not os.path.exists(file):
    if os.path.dirname(file):
      os.makedirs(os.path.dirname(file), exist_ok=True)
    df = reader(url, sep=sep, index_col=None)
    df.to_csv(file, sep=sep, index=False)
  return pd.read_csv(file, sep=sep, **kwargs)

# %%
ncbi_gene = fetch_save_read(url, file)
ncbi_gene.head()
# Out:
#    #tax_id  GeneID Symbol LocusTag                   Synonyms  \
# 0     9606       1   A1BG        -       A1B|ABG|GAB|HYST2477
# 1     9606       2    A2M        -  A2MD|CPAMD5|FWP007|S863-7
# 2     9606       3  A2MP1        -                       A2MP
# 3     9606       9   NAT1        -       AAC1|MNAT|NAT-1|NATI
# 4     9606      10   NAT2        -            AAC2|NAT-2|PNAT
#
#                                              dbXrefs chromosome map_location  \
# 0  MIM:138670|HGNC:HGNC:5|Ensembl:ENSG00000121410...         19     19q13.43
# 1  MIM:103950|HGNC:HGNC:7|Ensembl:ENSG00000175899...         12     12p13.31
# 2  HGNC:HGNC:8|Ensembl:ENSG00000291190|AllianceGe...         12     12p13.31
# 3  MIM:108345|HGNC:HGNC:7645|Ensembl:ENSG00000171...          8         8p22
# 4  MIM:612182|HGNC:HGNC:7646|Ensembl:ENSG00000156...          8         8p22
#
#                           description    type_of_gene  \
# 0              alpha-1-B glycoprotein  protein-coding
# 1               alpha-2-macroglobulin  protein-coding
# 2  alpha-2-macroglobulin pseudogene 1          pseudo
# 3               N-acetyltransferase 1  protein-coding
# 4               N-acetyltransferase 2  protein-coding
#
#   Symbol_from_nomenclature_authority Full_name_from_nomenclature_authority  \
# 0                               A1BG                alpha-1-B glycoprotein
# 1                                A2M                 alpha-2-macroglobulin
# 2                              A2MP1    alpha-2-macroglobulin pseudogene 1
# 3                               NAT1                 N-acetyltransferase 1
# 4                               NAT2                 N-acetyltransferase 2
#
#   Nomenclature_status                                 Other_designations  \
# 0                   O  alpha-1B-glycoprotein|HEL-S-163pA|epididymis s...
# 1                   O  alpha-2-macroglobulin|C3 and PZP-like alpha-2-...
# 2                   O                  pregnancy-zone protein pseudogene
# 3                   O  arylamine N-acetyltransferase 1|N-acetyltransf...
# 4                   O  arylamine N-acetyltransferase 2|N-acetyltransf...
#
#    Modification_date Feature_type
# 0           20220805            -
# 1           20221009            -
# 2           20221025            -
# 3           20220925            -
# 4           20221009            -

# %%
def maybe_split(record):
    ''' NCBI Stores Nulls as '-' and lists '|' delimited
    '''
    if record in {'', '-'}:
        return set()
    return set(record.split('|'))

def supplement_dbXref_prefix_omitted(ids):
    ''' NCBI Stores external IDS with Foreign:ID while most datasets just use the ID
    '''
    for id in ids:
        # add original id
        yield id
        # also add id *without* prefix
        if ':' in id:
            yield id.split(':', maxsplit=1)[1]

ncbi_gene['All_synonyms'] = [
    set.union(
      maybe_split(gene_info['Symbol']),
      maybe_split(gene_info['Symbol_from_nomenclature_authority']),
      maybe_split(str(gene_info['GeneID'])),
      maybe_split(gene_info['Synonyms']),
      maybe_split(gene_info['Other_designations']),
      maybe_split(gene_info['LocusTag']),
      set(supplement_dbXref_prefix_omitted(maybe_split(gene_info['dbXrefs']))),
    )
    for _, gene_info in ncbi_gene.iterrows()
  ]

ncbi_gene['All_synonyms'] = [
    set.union(
      maybe_split(gene_info['Symbol']),
      maybe_split(gene_info['Symbol_from_nomenclature_authority']),
      maybe_split(str(gene_info['GeneID'])),
      maybe_split(gene_info['Synonyms']),
      maybe_split(gene_info['Other_designations']),
      maybe_split(gene_info['LocusTag']),
      set(supplement_dbXref_prefix_omitted(maybe_split(gene_info['dbXrefs']))),
    )
    for _, gene_info in ncbi_gene.iterrows()
  ]

synonyms, gene_id = zip(*{
    (synonym, gene_info['Symbol'])
    for _, gene_info in ncbi_gene.iterrows()
    for synonym in gene_info['All_synonyms']
  })
ncbi_lookup_syn = pd.Series(gene_id, index=synonyms)
symbols, cap, gene_id = zip(*{
    (gene_info['Symbol'], gene_info['Symbol'].upper(), gene_info['Symbol'])
    for _, gene_info in ncbi_gene.iterrows()
  })
ncbi_lookup_sym = pd.Series(gene_id, index=symbols)
ncbi_lookup_sym_cap = pd.Series(gene_id, index=cap)

index_values = ncbi_lookup_syn.index.value_counts()
ambiguous = index_values[index_values > 1].index
ncbi_lookup_syn_disambiguated = ncbi_lookup_syn[(
(ncbi_lookup_syn.index == ncbi_lookup_syn) | (~ncbi_lookup_syn.index.isin(ambiguous))
)]
all_genes = {}

def gene_lookup(gene):
    gene_id = ncbi_lookup_sym.to_dict().get(gene)
    if gene_id: return str(gene_id)
    gene_id = ncbi_lookup_sym_cap.to_dict().get(gene)
    if gene_id: return str(gene_id)
    return str(ncbi_lookup_syn_disambiguated.to_dict().get(gene))

# %%
df = pd.read_csv('data/gwas_catalog_v1.0-associations_e109_r2023-05-20.tsv', sep="\t")
df.head()
# Out:
# /var/folders/wq/7bkxhy8j7ql194c1fbby4gy40000gn/T/ipykernel_2690/2743813533.py:1: DtypeWarning: Columns (9,11,12,23,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/gwas_catalog_v1.0-associations_e109_r2023-05-20.tsv', sep="\t")
#   DATE ADDED TO CATALOG  PUBMEDID FIRST AUTHOR        DATE     JOURNAL  \
# 0            2017-08-10  28443625   Justice AE  2017-04-26  Nat Commun
# 1            2017-08-10  28443625   Justice AE  2017-04-26  Nat Commun
# 2            2017-08-10  28443625   Justice AE  2017-04-26  Nat Commun
# 3            2017-08-10  28443625   Justice AE  2017-04-26  Nat Commun
# 4            2017-08-10  28443625   Justice AE  2017-04-26  Nat Commun
#
#                                    LINK  \
# 0  www.ncbi.nlm.nih.gov/pubmed/28443625
# 1  www.ncbi.nlm.nih.gov/pubmed/28443625
# 2  www.ncbi.nlm.nih.gov/pubmed/28443625
# 3  www.ncbi.nlm.nih.gov/pubmed/28443625
# 4  www.ncbi.nlm.nih.gov/pubmed/28443625
#
#                                                STUDY  \
# 0  Genome-wide meta-analysis of 241,258 adults ac...
# 1  Genome-wide meta-analysis of 241,258 adults ac...
# 2  Genome-wide meta-analysis of 241,258 adults ac...
# 3  Genome-wide meta-analysis of 241,258 adults ac...
# 4  Genome-wide meta-analysis of 241,258 adults ac...
#
#                           DISEASE/TRAIT  \
# 0  BMI (adjusted for smoking behaviour)
# 1  BMI (adjusted for smoking behaviour)
# 2  BMI (adjusted for smoking behaviour)
# 3  BMI (adjusted for smoking behaviour)
# 4  BMI (adjusted for smoking behaviour)
#
#                                  INITIAL SAMPLE SIZE  \
# 0  98,173 European ancestry women, 64,373 Europea...
# 1  98,173 European ancestry women, 64,373 Europea...
# 2  98,173 European ancestry women, 64,373 Europea...
# 3  98,173 European ancestry women, 64,373 Europea...
# 4  98,173 European ancestry women, 64,373 Europea...
#
#                              REPLICATION SAMPLE SIZE  ...  \
# 0  21,496 European ancestry women, 24,385 Europea...  ...
# 1  21,496 European ancestry women, 24,385 Europea...  ...
# 2  21,496 European ancestry women, 24,385 Europea...  ...
# 3  21,496 European ancestry women, 24,385 Europea...  ...
# 4  21,496 European ancestry women, 24,385 Europea...  ...
#
#                  CONTEXT INTERGENIC RISK ALLELE FREQUENCY       P-VALUE  \
# 0  upstream_gene_variant        1.0                0.7603  1.000000e-28
# 1         intron_variant        0.0                0.3933  2.000000e-06
# 2         intron_variant        0.0                0.3933  1.000000e-11
# 3         intron_variant        0.0                0.3933  1.000000e-07
# 4         intron_variant        0.0                0.1937  8.000000e-07
#
#   PVALUE_MLOG P-VALUE (TEXT) OR or BETA                 95% CI (TEXT)  \
# 0    28.00000        (women)     0.0542  [0.045-0.064] kg/m2 decrease
# 1     5.69897        (women)     0.0200  [0.012-0.028] kg/m2 increase
# 2    11.00000            NaN     0.0223  [0.016-0.029] kg/m2 increase
# 3     7.00000          (men)     0.0254  [0.016-0.035] kg/m2 increase
# 4     6.09691            NaN     0.0231  [0.014-0.032] kg/m2 increase
#
#                           PLATFORM [SNPS PASSING QC]  CNV
# 0  Affymetrix, Illumina, Perlegen [up to 2800000]...    N
# 1  Affymetrix, Illumina, Perlegen [up to 2800000]...    N
# 2  Affymetrix, Illumina, Perlegen [up to 2800000]...    N
# 3  Affymetrix, Illumina, Perlegen [up to 2800000]...    N
# 4  Affymetrix, Illumina, Perlegen [up to 2800000]...    N
#
# [5 rows x 34 columns]

# %%
cols = ['DISEASE/TRAIT', 
       'REPORTED GENE(S)', 'MAPPED_GENE', 'UPSTREAM_GENE_ID',
       'DOWNSTREAM_GENE_ID',  'SNP_GENE_IDS',  'P-VALUE', 'PVALUE_MLOG', 'P-VALUE (TEXT)',
       ]

df = df[cols]

# %%
df.head()
# Out:
#                           DISEASE/TRAIT REPORTED GENE(S)          MAPPED_GENE  \
# 0  BMI (adjusted for smoking behaviour)             MC4R  RPS3AP49 - RNU4-17P
# 1  BMI (adjusted for smoking behaviour)            MTCH2                MTCH2
# 2  BMI (adjusted for smoking behaviour)            MTCH2                MTCH2
# 3  BMI (adjusted for smoking behaviour)            MTCH2                MTCH2
# 4  BMI (adjusted for smoking behaviour)            MTIF3                MTIF3
#
#   UPSTREAM_GENE_ID DOWNSTREAM_GENE_ID     SNP_GENE_IDS       P-VALUE  \
# 0  ENSG00000242060    ENSG00000202468              NaN  1.000000e-28
# 1              NaN                NaN  ENSG00000109919  2.000000e-06
# 2              NaN                NaN  ENSG00000109919  1.000000e-11
# 3              NaN                NaN  ENSG00000109919  1.000000e-07
# 4              NaN                NaN  ENSG00000122033  8.000000e-07
#
#    PVALUE_MLOG P-VALUE (TEXT)
# 0     28.00000        (women)
# 1      5.69897        (women)
# 2     11.00000            NaN
# 3      7.00000          (men)
# 4      6.09691            NaN

# %%
len(set(df['DISEASE/TRAIT']))
# Out:
# 24929

# %%
all_genes = {}
for genes in tqdm(df['MAPPED_GENE'].unique()):
    if type(genes) == str:
        for g in genes.split(","):
            gene = g.strip()
            if gene not in all_genes:
                all_genes[gene] = ''
# Out:
# 100%|██████████| 44813/44813 [00:00<00:00, 1664476.51it/s]

# %%
len(all_genes)
# Out:
# 42757

# %%
for gene in tqdm(all_genes):
    all_genes[gene] = gene_lookup(gene)
# Out:
# 100%|██████████| 42757/42757 [2:39:36<00:00,  4.46it/s]

# %%
with open("output/all_genes.json", 'w') as o:
    o.write(json.dumps(all_genes))

# %%
gmt = {}
none_counter = {}
for i, row in tqdm(df.iterrows()):
    disease = row['DISEASE/TRAIT']
    if disease not in gmt:
        gmt[disease] = set()
    genes = row["MAPPED_GENE"]
    if type(genes) == str:
        for g in genes.split(","):
            gene = all_genes[g.strip()]
            if gene != 'None':
                gmt[disease].add(gene)
            else:
                if g.strip() not in none_counter:
                    none_counter[g.strip()] = 0
                none_counter[g.strip()] += 1
# Out:
# 519421it [00:08, 59273.67it/s]

# %%
len(none_counter)
# Out:
# 23858

# %%
len(gmt)
# Out:
# 24929

# %%
import csv

# %%
with open('output/GWAS_Catalog_2023.gmt', 'w') as o:
    csv_writer = csv.writer(o, delimiter="\t")
    for k,v in gmt.items():
        if len(v) >= 5:
            row = [k, ''] + list(v)
            csv_writer.writerow(row)
