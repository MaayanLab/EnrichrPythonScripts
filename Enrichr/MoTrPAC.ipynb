# %%
import pandas as pd
from glob import glob
import csv

# %%
feature_df = pd.read_csv("analysis/transcript-rna-seq/feature-annot/TRNSCRPT_FEATURE_ANNOT.txt", sep="\t")
feature_df.head()
# Out:
#           seqname   source feature  start    end score strand frame  \
# 0  AABR07022258.1  ensembl    gene    405    848     .      -     .
# 1  AABR07022620.1  ensembl    gene    122    427     .      -     .
# 2  AABR07022926.1  ensembl    gene     18     85     .      +     .
# 3  AABR07024031.1  ensembl    gene  18673  58717     .      -     .
# 4  AABR07024032.1  ensembl    gene  17425  17528     .      -     .
#
#               gene_id  gene_version       gene_name gene_source  \
# 0  ENSRNOG00000055633             1    LOC100910067     ensembl
# 1  ENSRNOG00000058846             1  AABR07022620.1     ensembl
# 2  ENSRNOG00000055717             1  AABR07022926.1     ensembl
# 3  ENSRNOG00000017648             7          Vom2r8     ensembl
# 4  ENSRNOG00000056404             1         RF00026     ensembl
#
#      gene_biotype
# 0  protein_coding
# 1  protein_coding
# 2           miRNA
# 3  protein_coding
# 4           snRNA

# %%
gene_mapper = {}
for i, row in feature_df.iterrows():
    gene_id = row["gene_id"]
    gene_name = row["gene_name"]
    gene_mapper[gene_id] = gene_name

# %% [markdown]
# ## Sex and Timepoint Comparison
# * Training group (timepoint) vs sex-matched controls
# * We filter the dataframe for genes that have an adjusted p-value < 0.05. We then get the up and down differentially expressed genes for each specific tissue, sex, and timepoint group.

# %%
filename = "analysis/transcript-rna-seq/dea/pass1b-06_t62-spleen_transcript-rna-seq_timewise-dea-fdr_20211008.txt"
tw = pd.read_csv(filename, sep="\t")
tw.head(10)
# Out:
#            feature_ID      tissue     sex comparison_group  \
# 0  ENSRNOG00000000001  t62-spleen    male               1w
# 1  ENSRNOG00000000001  t62-spleen    male               2w
# 2  ENSRNOG00000000001  t62-spleen    male               4w
# 3  ENSRNOG00000000001  t62-spleen    male               8w
# 4  ENSRNOG00000000001  t62-spleen  female               1w
# 5  ENSRNOG00000000001  t62-spleen  female               2w
# 6  ENSRNOG00000000001  t62-spleen  female               4w
# 7  ENSRNOG00000000001  t62-spleen  female               8w
# 8  ENSRNOG00000000008  t62-spleen    male               1w
# 9  ENSRNOG00000000008  t62-spleen    male               2w
#
#                 assay                                  covariates  \
# 0  transcript-rna-seq  pct_globin,rin,pct_umi_dup,median_5_3_bias
# 1  transcript-rna-seq  pct_globin,rin,pct_umi_dup,median_5_3_bias
# 2  transcript-rna-seq  pct_globin,rin,pct_umi_dup,median_5_3_bias
# 3  transcript-rna-seq  pct_globin,rin,pct_umi_dup,median_5_3_bias
# 4  transcript-rna-seq  pct_globin,rin,pct_umi_dup,median_5_3_bias
# 5  transcript-rna-seq  pct_globin,rin,pct_umi_dup,median_5_3_bias
# 6  transcript-rna-seq  pct_globin,rin,pct_umi_dup,median_5_3_bias
# 7  transcript-rna-seq  pct_globin,rin,pct_umi_dup,median_5_3_bias
# 8  transcript-rna-seq  pct_globin,rin,pct_umi_dup,median_5_3_bias
# 9  transcript-rna-seq  pct_globin,rin,pct_umi_dup,median_5_3_bias
#
#    removed_samples     logFC  logFC_se  shrunk_logFC  shrunk_logFC_se  \
# 0              NaN  0.106894  0.526792  2.387733e-04         0.024905
# 1              NaN -0.009610  0.577451 -2.057732e-05         0.026721
# 2              NaN -0.056960  0.523416 -9.578498e-05         0.021470
# 3              NaN  0.627636  0.503587  2.131641e-02         0.094573
# 4              NaN  0.198305  0.560630  6.254192e-04         0.031551
# 5              NaN -0.331535  0.645398 -5.570160e-04         0.026494
# 6              NaN  0.000136  0.481579  6.983907e-09         0.003456
# 7              NaN  0.058231  0.440509  4.784217e-04         0.039949
# 8              NaN -0.646087  0.491763 -1.675895e-03         0.025519
# 9              NaN -0.600313  0.536082 -1.506895e-03         0.027309
#
#      zscore   p_value  comparison_average_intensity  \
# 0  0.202916  0.839201                      9.466459
# 1 -0.016642  0.986722                      8.348006
# 2 -0.108823  0.913343                      9.995616
# 3  1.246331  0.212643                     14.985300
# 4  0.353718  0.723550                     12.607312
# 5 -0.513690  0.607468                      8.048467
# 6  0.000282  0.999775                     10.175191
# 7  0.132191  0.894834                     10.417179
# 8 -1.313817  0.188908                      7.980267
# 9 -1.119814  0.262793                      6.443191
#
#    comparison_average_intensity_se  reference_average_intensity  \
# 0                         1.499481                     8.785202
# 1                         1.503956                     8.785202
# 2                         2.264256                     8.785202
# 3                         2.621802                     8.785202
# 4                         1.186143                     9.859512
# 5                         0.590803                     9.859512
# 6                         2.228992                     9.859512
# 7                         1.967804                     9.859512
# 8                         1.389427                    12.579924
# 9                         1.643377                    12.579924
#
#    reference_average_intensity_se  adj_p_value tissue_abbreviation  \
# 0                        2.113512          1.0              SPLEEN
# 1                        2.113512          1.0              SPLEEN
# 2                        2.113512          1.0              SPLEEN
# 3                        2.113512          1.0              SPLEEN
# 4                        0.574047          1.0              SPLEEN
# 5                        0.574047          1.0              SPLEEN
# 6                        0.574047          1.0              SPLEEN
# 7                        0.574047          1.0              SPLEEN
# 8                        0.896894          1.0              SPLEEN
# 9                        0.896894          1.0              SPLEEN
#
#    selection_fdr
# 0            1.0
# 1            1.0
# 2            1.0
# 3            1.0
# 4            1.0
# 5            1.0
# 6            1.0
# 7            1.0
# 8            1.0
# 9            1.0

# %%
tw.head()[['feature_ID', 'tissue', 'sex', 'comparison_group', 'logFC',  'p_value', 'adj_p_value', 'tissue_abbreviation',
       'selection_fdr']]
# Out:
#            feature_ID      tissue     sex comparison_group     logFC  \
# 0  ENSRNOG00000000001  t62-spleen    male               1w  0.106894
# 1  ENSRNOG00000000001  t62-spleen    male               2w -0.009610
# 2  ENSRNOG00000000001  t62-spleen    male               4w -0.056960
# 3  ENSRNOG00000000001  t62-spleen    male               8w  0.627636
# 4  ENSRNOG00000000001  t62-spleen  female               1w  0.198305
#
#     p_value  adj_p_value tissue_abbreviation  selection_fdr
# 0  0.839201          1.0              SPLEEN            1.0
# 1  0.986722          1.0              SPLEEN            1.0
# 2  0.913343          1.0              SPLEEN            1.0
# 3  0.212643          1.0              SPLEEN            1.0
# 4  0.723550          1.0              SPLEEN            1.0

# %%
with open("MoTrPAC_timewise_2023.gmt", "w") as o:
    csv_writer = csv.writer(o, delimiter="\t")
    for filename in glob("analysis/transcript-rna-seq/dea/*timewise*.txt"):
        print(filename)
        df = pd.read_csv(filename, sep="\t")
        tissues = df.tissue.unique()
        sexes = df.sex.unique()
        groups = df.comparison_group.unique()
        
        for tissue in tissues:
            for sex in sexes:
                for timepoint in groups:
                    label = "%s_%s_%s"%(tissue, sex, timepoint)
                    up_genes = set()
                    down_genes = set()
                    d = df[(df.tissue == tissue) & (df.sex == sex) & (df.comparison_group == timepoint) & (df.adj_p_value < 0.05)] 
                    up = d[d.logFC > 0]
                    up_genes = set([gene_mapper[i] for i in up.feature_ID])

                    down = d[d.logFC < 0]
                    down_genes = set([gene_mapper[i] for i in down.feature_ID])
                    if (len(up_genes) >= 5):
                        csv_writer.writerow([
                            label + "_up",
                            "",
                            *list(up_genes)
                        ])
                    if (len(down_genes) >= 5):
                        csv_writer.writerow([
                            label + "_down",
                            "",
                            *list(down_genes)
                        ])
# Out:
# analysis/transcript-rna-seq/dea/pass1b-06_t61-colon_transcript-rna-seq_timewise-dea-fdr_20211008.txt
# analysis/transcript-rna-seq/dea/pass1b-06_t56-vastus-lateralis_transcript-rna-seq_timewise-dea-fdr_20211008.txt
# analysis/transcript-rna-seq/dea/pass1b-06_t55-gastrocnemius_transcript-rna-seq_timewise-dea-fdr_20211008.txt
# analysis/transcript-rna-seq/dea/pass1b-06_t62-spleen_transcript-rna-seq_timewise-dea-fdr_20211008.txt
# analysis/transcript-rna-seq/dea/pass1b-06_t58-heart_transcript-rna-seq_timewise-dea-fdr_20211008.txt
# analysis/transcript-rna-seq/dea/pass1b-06_t59-kidney_transcript-rna-seq_timewise-dea-fdr_20211008.txt
# analysis/transcript-rna-seq/dea/pass1b-06_t66-lung_transcript-rna-seq_timewise-dea-fdr_20211008.txt
# analysis/transcript-rna-seq/dea/pass1b-06_t53-cortex_transcript-rna-seq_timewise-dea-fdr_20211008.txt
# analysis/transcript-rna-seq/dea/pass1b-06_t60-adrenal_transcript-rna-seq_timewise-dea-fdr_20211008.txt
# analysis/transcript-rna-seq/dea/pass1b-06_t68-liver_transcript-rna-seq_timewise-dea-fdr_20211008.txt
# analysis/transcript-rna-seq/dea/pass1b-06_t99-vena-cava_transcript-rna-seq_timewise-dea-fdr_20211008.txt
# analysis/transcript-rna-seq/dea/pass1b-06_t67-small-intestine_transcript-rna-seq_timewise-dea-fdr_20211008.txt
# analysis/transcript-rna-seq/dea/pass1b-06_t69-brown-adipose_transcript-rna-seq_timewise-dea-fdr_20211008.txt
# analysis/transcript-rna-seq/dea/pass1b-06_t70-white-adipose_transcript-rna-seq_timewise-dea-fdr_20211008.txt
# analysis/transcript-rna-seq/dea/pass1b-06_t52-hippocampus_transcript-rna-seq_timewise-dea-fdr_20211008.txt
# analysis/transcript-rna-seq/dea/pass1b-06_t54-hypothalamus_transcript-rna-seq_timewise-dea-fdr_20211008.txt
# analysis/transcript-rna-seq/dea/pass1b-06_t63-testes_transcript-rna-seq_timewise-dea-fdr_20211008.txt
# analysis/transcript-rna-seq/dea/pass1b-06_t30-blood-rna_transcript-rna-seq_timewise-dea-fdr_20211008.txt
# analysis/transcript-rna-seq/dea/pass1b-06_t64-ovaries_transcript-rna-seq_timewise-dea-fdr_20211008.txt

# %% [markdown]
# ## Training Response Significance
# * Computed genes that changed over the training time course computed using likelihood ratio test.
# * We filter the dataframe for genes that have an adjusted training p-value < 0.05. These are the genes that significantly responded over the course of the raining time.

# %%
filename = "analysis/transcript-rna-seq/dea/pass1b-06_t62-spleen_transcript-rna-seq_training-dea-fdr_20211008.txt"
tr = pd.read_csv(filename, sep="\t")
tr.head(10)
# Out:
#            feature_ID               assay      tissue  removed_samples  \
# 0  ENSRNOG00000000001  transcript-rna-seq  t62-spleen              NaN
# 1  ENSRNOG00000000008  transcript-rna-seq  t62-spleen              NaN
# 2  ENSRNOG00000000010  transcript-rna-seq  t62-spleen              NaN
# 3  ENSRNOG00000000012  transcript-rna-seq  t62-spleen              NaN
# 4  ENSRNOG00000000017  transcript-rna-seq  t62-spleen              NaN
# 5  ENSRNOG00000000021  transcript-rna-seq  t62-spleen              NaN
# 6  ENSRNOG00000000024  transcript-rna-seq  t62-spleen              NaN
# 7  ENSRNOG00000000033  transcript-rna-seq  t62-spleen              NaN
# 8  ENSRNOG00000000034  transcript-rna-seq  t62-spleen              NaN
# 9  ENSRNOG00000000036  transcript-rna-seq  t62-spleen              NaN
#
#     lrt_male  p_value_male                                    full_model_male  \
# 0   2.651426      0.617741  ~pct_globin+rin+pct_umi_dup+median_5_3_bias+group
# 1   2.211815      0.696867  ~pct_globin+rin+pct_umi_dup+median_5_3_bias+group
# 2   1.149430      0.886352  ~pct_globin+rin+pct_umi_dup+median_5_3_bias+group
# 3  11.889917      0.018189  ~pct_globin+rin+pct_umi_dup+median_5_3_bias+group
# 4   2.377714      0.666658  ~pct_globin+rin+pct_umi_dup+median_5_3_bias+group
# 5   2.929890      0.569626  ~pct_globin+rin+pct_umi_dup+median_5_3_bias+group
# 6   4.319273      0.364518  ~pct_globin+rin+pct_umi_dup+median_5_3_bias+group
# 7   6.408972      0.170617  ~pct_globin+rin+pct_umi_dup+median_5_3_bias+group
# 8  18.942355      0.000807  ~pct_globin+rin+pct_umi_dup+median_5_3_bias+group
# 9  10.579231      0.031723  ~pct_globin+rin+pct_umi_dup+median_5_3_bias+group
#
#                             reduced_model_male  lrt_female  p_value_female  \
# 0  ~pct_globin+rin+pct_umi_dup+median_5_3_bias    1.071593        0.898753
# 1  ~pct_globin+rin+pct_umi_dup+median_5_3_bias    0.914729        0.922438
# 2  ~pct_globin+rin+pct_umi_dup+median_5_3_bias    1.891004        0.755797
# 3  ~pct_globin+rin+pct_umi_dup+median_5_3_bias    8.933280        0.062789
# 4  ~pct_globin+rin+pct_umi_dup+median_5_3_bias    3.039546        0.551229
# 5  ~pct_globin+rin+pct_umi_dup+median_5_3_bias    6.986178        0.136620
# 6  ~pct_globin+rin+pct_umi_dup+median_5_3_bias    6.980177        0.136939
# 7  ~pct_globin+rin+pct_umi_dup+median_5_3_bias   15.018139        0.004664
# 8  ~pct_globin+rin+pct_umi_dup+median_5_3_bias    2.166775        0.705116
# 9  ~pct_globin+rin+pct_umi_dup+median_5_3_bias    2.925815        0.570316
#
#                                    full_model_female  \
# 0  ~pct_globin+rin+pct_umi_dup+median_5_3_bias+group
# 1  ~pct_globin+rin+pct_umi_dup+median_5_3_bias+group
# 2  ~pct_globin+rin+pct_umi_dup+median_5_3_bias+group
# 3  ~pct_globin+rin+pct_umi_dup+median_5_3_bias+group
# 4  ~pct_globin+rin+pct_umi_dup+median_5_3_bias+group
# 5  ~pct_globin+rin+pct_umi_dup+median_5_3_bias+group
# 6  ~pct_globin+rin+pct_umi_dup+median_5_3_bias+group
# 7  ~pct_globin+rin+pct_umi_dup+median_5_3_bias+group
# 8  ~pct_globin+rin+pct_umi_dup+median_5_3_bias+group
# 9  ~pct_globin+rin+pct_umi_dup+median_5_3_bias+group
#
#                           reduced_model_female   p_value  lrt  full_model  \
# 0  ~pct_globin+rin+pct_umi_dup+median_5_3_bias  0.881892  NaN         NaN
# 1  ~pct_globin+rin+pct_umi_dup+median_5_3_bias  0.926875  NaN         NaN
# 2  ~pct_globin+rin+pct_umi_dup+median_5_3_bias  0.938281  NaN         NaN
# 3  ~pct_globin+rin+pct_umi_dup+median_5_3_bias  0.008879  NaN         NaN
# 4  ~pct_globin+rin+pct_umi_dup+median_5_3_bias  0.735361  NaN         NaN
# 5  ~pct_globin+rin+pct_umi_dup+median_5_3_bias  0.276529  NaN         NaN
# 6  ~pct_globin+rin+pct_umi_dup+median_5_3_bias  0.199538  NaN         NaN
# 7  ~pct_globin+rin+pct_umi_dup+median_5_3_bias  0.006474  NaN         NaN
# 8  ~pct_globin+rin+pct_umi_dup+median_5_3_bias  0.004819  NaN         NaN
# 9  ~pct_globin+rin+pct_umi_dup+median_5_3_bias  0.090683  NaN         NaN
#
#    reduced_model  adj_p_value tissue_abbreviation
# 0            NaN     1.000000              SPLEEN
# 1            NaN     1.000000              SPLEEN
# 2            NaN     1.000000              SPLEEN
# 3            NaN     0.076572              SPLEEN
# 4            NaN     1.000000              SPLEEN
# 5            NaN     0.616488              SPLEEN
# 6            NaN     0.518020              SPLEEN
# 7            NaN     0.072793              SPLEEN
# 8            NaN     0.049617              SPLEEN
# 9            NaN     0.325494              SPLEEN

# %%
tr.head()[['feature_ID','tissue', 'lrt_male',
       'p_value_male', 'lrt_female',
       'p_value_female', 'p_value', 'lrt', 'adj_p_value',
       'tissue_abbreviation']]
# Out:
#            feature_ID      tissue   lrt_male  p_value_male  lrt_female  \
# 0  ENSRNOG00000000001  t62-spleen   2.651426      0.617741    1.071593
# 1  ENSRNOG00000000008  t62-spleen   2.211815      0.696867    0.914729
# 2  ENSRNOG00000000010  t62-spleen   1.149430      0.886352    1.891004
# 3  ENSRNOG00000000012  t62-spleen  11.889917      0.018189    8.933280
# 4  ENSRNOG00000000017  t62-spleen   2.377714      0.666658    3.039546
#
#    p_value_female   p_value  lrt  adj_p_value tissue_abbreviation
# 0        0.898753  0.881892  NaN     1.000000              SPLEEN
# 1        0.922438  0.926875  NaN     1.000000              SPLEEN
# 2        0.755797  0.938281  NaN     1.000000              SPLEEN
# 3        0.062789  0.008879  NaN     0.076572              SPLEEN
# 4        0.551229  0.735361  NaN     1.000000              SPLEEN

# %%
with open("MoTrPAC_training_significance_2023.gmt", "w") as o:
    csv_writer = csv.writer(o, delimiter="\t")
    for filename in glob("analysis/transcript-rna-seq/dea/*training*.txt"):
        df = pd.read_csv(filename, sep="\t")
        tissues = df.tissue.unique()
        for tissue in tissues:
                up_genes = set()
                down_genes = set()
                d = df[(df.tissue == tissue) & (df.adj_p_value < 0.05)] 
                genes = set([gene_mapper[i] for i in d.feature_ID])

                if (len(genes) >= 5):
                    print(filename, len(genes))
                    csv_writer.writerow([
                        tissue,
                        "",
                        *list(genes)
                    ])
# Out:
# analysis/transcript-rna-seq/dea/pass1b-06_t62-spleen_transcript-rna-seq_training-dea-fdr_20211008.txt 1099
# analysis/transcript-rna-seq/dea/pass1b-06_t61-colon_transcript-rna-seq_training-dea-fdr_20211008.txt 2515
# analysis/transcript-rna-seq/dea/pass1b-06_t56-vastus-lateralis_transcript-rna-seq_training-dea-fdr_20211008.txt 764
# analysis/transcript-rna-seq/dea/pass1b-06_t55-gastrocnemius_transcript-rna-seq_training-dea-fdr_20211008.txt 565
# analysis/transcript-rna-seq/dea/pass1b-06_t66-lung_transcript-rna-seq_training-dea-fdr_20211008.txt 961
# analysis/transcript-rna-seq/dea/pass1b-06_t59-kidney_transcript-rna-seq_training-dea-fdr_20211008.txt 338
# analysis/transcript-rna-seq/dea/pass1b-06_t58-heart_transcript-rna-seq_training-dea-fdr_20211008.txt 720
# analysis/transcript-rna-seq/dea/pass1b-06_t67-small-intestine_transcript-rna-seq_training-dea-fdr_20211008.txt 746
# analysis/transcript-rna-seq/dea/pass1b-06_t69-brown-adipose_transcript-rna-seq_training-dea-fdr_20211008.txt 1631
# analysis/transcript-rna-seq/dea/pass1b-06_t99-vena-cava_transcript-rna-seq_training-dea-fdr_20211008.txt 90
# analysis/transcript-rna-seq/dea/pass1b-06_t60-adrenal_transcript-rna-seq_training-dea-fdr_20211008.txt 4489
# analysis/transcript-rna-seq/dea/pass1b-06_t68-liver_transcript-rna-seq_training-dea-fdr_20211008.txt 276
# analysis/transcript-rna-seq/dea/pass1b-06_t53-cortex_transcript-rna-seq_training-dea-fdr_20211008.txt 105
# analysis/transcript-rna-seq/dea/pass1b-06_t64-ovaries_transcript-rna-seq_training-dea-fdr_20211008.txt 896
# analysis/transcript-rna-seq/dea/pass1b-06_t30-blood-rna_transcript-rna-seq_training-dea-fdr_20211008.txt 1575
# analysis/transcript-rna-seq/dea/pass1b-06_t52-hippocampus_transcript-rna-seq_training-dea-fdr_20211008.txt 244
# analysis/transcript-rna-seq/dea/pass1b-06_t70-white-adipose_transcript-rna-seq_training-dea-fdr_20211008.txt 1741
# analysis/transcript-rna-seq/dea/pass1b-06_t63-testes_transcript-rna-seq_training-dea-fdr_20211008.txt 107
# analysis/transcript-rna-seq/dea/pass1b-06_t54-hypothalamus_transcript-rna-seq_training-dea-fdr_20211008.txt 16

# %%
# s1 = pd.read_csv("s1.tsv", sep="\t")
# s1.head()

# %%
# s1 = s1[s1.assay == "TRNSCRPT"]
# s1.head()

# %%
# tr[tr.adj_p_value < 0.05].head()

# %%
# feature_id = "ENSRNOG00000000034"
# s1[(s1.tissue == "SPLEEN") & (s1.feature_ID == feature_id)]

# %%
# tw[tw.feature_ID == feature_id]
