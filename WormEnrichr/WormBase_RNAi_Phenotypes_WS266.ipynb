# %% [markdown]
# # RNAi Phenotypes Wormbase (WS266)

# %% [markdown]
# Author: Zachary Flamholz
# Date: 06-2018
# Database: https://wormbase.org/#012-34-5
# Data: ftp://ftp.wormbase.org/pub/wormbase/releases/WS266/ONTOLOGY/rnai_phenotypes.WS266.wb
# Companion file: http://ftp.ncbi.nlm.nih.gov/gene/DATA/GENE_INFO/Invertebrates/Caenorhabditis_elegans.gene_info.gz,  http://tazendra.caltech.edu/~azurebrd/cgi-bin/forms/generic.cgi?action=WpaXref

# %% [markdown]
# # Versions of Modules in Use

# %%
# %load_ext version_information
# %version_information numpy, pandas
# Out:
# The version_information extension is already loaded. To reload it, use:
#   %reload_ext version_information
# Software versions
# Python 2.7.15 64bit [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]
# IPython 5.7.0
# OS Darwin 17.5.0 x86_64 i386 64bit
# numpy 1.14.3
# pandas 0.23.0
# Mon Jul 30 10:29:38 2018 EDT

# %% [markdown]
# ## import libraries

# %%
import numpy as np
import pandas as pd
import sys
import datetime
import scipy.stats as stat

# %% [markdown]
# ## read in data

# %%
df = pd.read_csv("input/rnai_phenotypes.WS266_WormBase.txt", sep="\t", header=None)
df.columns = ["WB gene ID", "Gene symbol", "phenotype", "WB phenotype ID", "WB source ID"]

# %%
df.head()
# Out:
#        WB gene ID Gene symbol                                       phenotype  \
# 0  WBGene00001908     F17E9.9                              locomotion variant
# 1  WBGene00001908     F17E9.9                           avoids bacterial lawn
# 2  WBGene00001908     F17E9.9  RAB-11 recycling endosome localization variant
# 3  WBGene00001908     F17E9.9                       body elongation defective
# 4  WBGene00001908     F17E9.9                  chromosome segregation variant
#
#        WB phenotype ID                                       WB source ID
# 0  WBPhenotype:0000643  WBRNAi00025129|WBPaper00006395 WBRNAi00025631|...
# 1  WBPhenotype:0000402                     WBRNAi00095640|WBPaper00040984
# 2  WBPhenotype:0002107                     WBRNAi00090830|WBPaper00041129
# 3  WBPhenotype:0000242                     WBRNAi00082054|WBPaper00005085
# 4  WBPhenotype:0000773                     WBRNAi00082059|WBPaper00005085

# %%
df.shape
# Out:
# (54934, 5)

# %%
len(df["phenotype"].unique())
# Out:
# 1223

# %%
len(df["Gene symbol"].unique())
# Out:
# 8106

# %%
df_location_variant = df.loc[df["phenotype"] == "locomotion variant"].copy()

# %%
df_location_variant.iloc[0]
# Out:
# WB gene ID                                            WBGene00001908
# Gene symbol                                                  F17E9.9
# phenotype                                         locomotion variant
# WB phenotype ID                                  WBPhenotype:0000643
# WB source ID       WBRNAi00025129|WBPaper00006395 WBRNAi00025631|...
# Name: 0, dtype: object

# %%
df_location_variant.iloc[0]["WB gene ID"]
# Out:
# 'WBGene00001908'

# %% [markdown]
# ## analyze term set

# %%
count_terms = lambda x: len(df.loc[df["phenotype"] == x])
func = np.vectorize(count_terms)
numGenes_perTerms = func(df["phenotype"].unique())

# %%
np.mean(numGenes_perTerms)
# Out:
# 44.91741618969746

# %%
np.median(numGenes_perTerms)
# Out:
# 6.0

# %% [markdown]
# ## convert gene symbol column to general nomenclature

# %%
cElegans_geneInfo = pd.read_csv("input/Caenorhabditis_elegans.gene_info", sep="\t")

# %%
cElegans_geneInfo.head()
# Out:
#    #tax_id  GeneID  Symbol       LocusTag Synonyms                  dbXrefs  \
# 0     6239  171590  homt-1  CELE_Y74C9A.3        -  WormBase:WBGene00022277
# 1     6239  171591  nlp-40  CELE_Y74C9A.2        -  WormBase:WBGene00022276
# 2     6239  171592  rcor-1  CELE_Y74C9A.4        -  WormBase:WBGene00022278
# 3     6239  171593  sesn-1  CELE_Y74C9A.5        -  WormBase:WBGene00022279
# 4     6239  171594   pgs-1  CELE_Y48G1C.4        -  WormBase:WBGene00021677
#
#   chromosome map_location                                        description  \
# 0          I            -       Alpha N-terminal protein methyltransferase 1
# 1          I            -                                         Peptide P4
# 2          I            -                   RCOR (REST CO-Repressor) homolog
# 3          I            -                                    Sestrin homolog
# 4          I            -  CDP-diacylglycerol--glycerol-3-phosphate 3-pho...
#
#      type_of_gene Symbol_from_nomenclature_authority  \
# 0  protein-coding                                  -
# 1  protein-coding                                  -
# 2  protein-coding                                  -
# 3  protein-coding                                  -
# 4  protein-coding                                  -
#
#   Full_name_from_nomenclature_authority Nomenclature_status  \
# 0                                     -                   -
# 1                                     -                   -
# 2                                     -                   -
# 3                                     -                   -
# 4                                     -                   -
#
#                                   Other_designations  Modification_date  \
# 0       Alpha N-terminal protein methyltransferase 1           20180606
# 1                                         Peptide P4           20180606
# 2                   RCOR (REST CO-Repressor) homolog           20180606
# 3                                    Sestrin homolog           20180606
# 4  CDP-diacylglycerol--glycerol-3-phosphate 3-pho...           20180406
#
#   Feature_type
# 0            -
# 1            -
# 2            -
# 3            -
# 4            -

# %%
cElegans_geneInfo.iloc[0,5].split(":")[1]
# Out:
# 'WBGene00022277'

# %%
remove_WormBase = lambda x: x.replace("|", ":").split(":")[1] if "WormBase" in x else x
## there are two rows that have muliple dbXrefs 
cElegans_geneInfo["dbXrefs"] = cElegans_geneInfo["dbXrefs"].apply(remove_WormBase)
cElegans_geneInfo.head()
# Out:
#    #tax_id  GeneID  Symbol       LocusTag Synonyms         dbXrefs chromosome  \
# 0     6239  171590  homt-1  CELE_Y74C9A.3        -  WBGene00022277          I
# 1     6239  171591  nlp-40  CELE_Y74C9A.2        -  WBGene00022276          I
# 2     6239  171592  rcor-1  CELE_Y74C9A.4        -  WBGene00022278          I
# 3     6239  171593  sesn-1  CELE_Y74C9A.5        -  WBGene00022279          I
# 4     6239  171594   pgs-1  CELE_Y48G1C.4        -  WBGene00021677          I
#
#   map_location                                        description  \
# 0            -       Alpha N-terminal protein methyltransferase 1
# 1            -                                         Peptide P4
# 2            -                   RCOR (REST CO-Repressor) homolog
# 3            -                                    Sestrin homolog
# 4            -  CDP-diacylglycerol--glycerol-3-phosphate 3-pho...
#
#      type_of_gene Symbol_from_nomenclature_authority  \
# 0  protein-coding                                  -
# 1  protein-coding                                  -
# 2  protein-coding                                  -
# 3  protein-coding                                  -
# 4  protein-coding                                  -
#
#   Full_name_from_nomenclature_authority Nomenclature_status  \
# 0                                     -                   -
# 1                                     -                   -
# 2                                     -                   -
# 3                                     -                   -
# 4                                     -                   -
#
#                                   Other_designations  Modification_date  \
# 0       Alpha N-terminal protein methyltransferase 1           20180606
# 1                                         Peptide P4           20180606
# 2                   RCOR (REST CO-Repressor) homolog           20180606
# 3                                    Sestrin homolog           20180606
# 4  CDP-diacylglycerol--glycerol-3-phosphate 3-pho...           20180406
#
#   Feature_type
# 0            -
# 1            -
# 2            -
# 3            -
# 4            -

# %% [markdown]
# ## testing how to convert names

# %%
type(cElegans_geneInfo["dbXrefs"][0])
# Out:
# str

# %%
type(df.iloc[0,0])
# Out:
# str

# %%
cElegans_geneInfo.loc[cElegans_geneInfo["dbXrefs"] == df.iloc[0,0]]["Symbol"]
# Out:
# 17913    his-34
# Name: Symbol, dtype: object

# %%
'WBGene00022277' in cElegans_geneInfo["dbXrefs"].values
# Out:
# True

# %%
df_location_variant.head(10)
# Out:
#          WB gene ID Gene symbol           phenotype      WB phenotype ID  \
# 0    WBGene00001908     F17E9.9  locomotion variant  WBPhenotype:0000643
# 57   WBGene00007110    B0035.11  locomotion variant  WBPhenotype:0000643
# 118  WBGene00006707     R09B3.4  locomotion variant  WBPhenotype:0000643
# 168  WBGene00003808     T05A1.1  locomotion variant  WBPhenotype:0000643
# 185  WBGene00016250    C30C11.4  locomotion variant  WBPhenotype:0000643
# 227  WBGene00012735    Y40B1A.4  locomotion variant  WBPhenotype:0000643
# 290  WBGene00004951    K10B3.10  locomotion variant  WBPhenotype:0000643
# 356  WBGene00017678     F21F8.4  locomotion variant  WBPhenotype:0000643
# 394  WBGene00019778       M57.2  locomotion variant  WBPhenotype:0000643
# 536  WBGene00019881     R05D3.8  locomotion variant  WBPhenotype:0000643
#
#                                           WB source ID
# 0    WBRNAi00025129|WBPaper00006395 WBRNAi00025631|...
# 57                      WBRNAi00024350|WBPaper00006395
# 118                     WBRNAi00026070|WBPaper00006395
# 168                     WBRNAi00075428|WBPaper00006132
# 185                     WBRNAi00024683|WBPaper00006395
# 227  WBRNAi00004607|WBPaper00004402 WBRNAi00026682|...
# 290  WBRNAi00008979|WBPaper00005654 WBRNAi00025934|...
# 356                     WBRNAi00078339|WBPaper00027214
# 394  WBRNAi00009019|WBPaper00005654 WBRNAi00026001|...
# 536  WBRNAi00026026|WBPaper00006395 WBRNAi00074594|...

# %%
type(cElegans_geneInfo.loc[cElegans_geneInfo["dbXrefs"] == 'WBGene00001908']["Symbol"].tolist()[0])
# Out:
# str

# %%
## if there is no WB gene ID in the reference table then the symbol becomes the WB gene ID from the phenotype list
change_name = lambda x: cElegans_geneInfo.loc[cElegans_geneInfo["dbXrefs"] == x]["Symbol"].tolist()[0] if x in cElegans_geneInfo["dbXrefs"].values else x
df_location_variant["Gene symbol"] = df_location_variant["WB gene ID"].apply(change_name)

# %%
df_location_variant.head(100)
# Out:
#           WB gene ID     Gene symbol           phenotype      WB phenotype ID  \
# 0     WBGene00001908          his-34  locomotion variant  WBPhenotype:0000643
# 57    WBGene00007110           leo-1  locomotion variant  WBPhenotype:0000643
# 118   WBGene00006707          ubc-12  locomotion variant  WBPhenotype:0000643
# 168   WBGene00003808           npr-2  locomotion variant  WBPhenotype:0000643
# 185   WBGene00016250         hsp-110  locomotion variant  WBPhenotype:0000643
# 227   WBGene00012735          sptf-3  locomotion variant  WBPhenotype:0000643
# 290   WBGene00004951           spc-1  locomotion variant  WBPhenotype:0000643
# 356   WBGene00017678          asp-12  locomotion variant  WBPhenotype:0000643
# 394   WBGene00019778           M57.2  locomotion variant  WBPhenotype:0000643
# 536   WBGene00019881         R05D3.8  locomotion variant  WBPhenotype:0000643
# 566   WBGene00006698           uaf-2  locomotion variant  WBPhenotype:0000643
# 604   WBGene00001694           grd-5  locomotion variant  WBPhenotype:0000643
# 639   WBGene00006745           unc-5  locomotion variant  WBPhenotype:0000643
# 655   WBGene00003171           mec-7  locomotion variant  WBPhenotype:0000643
# 707   WBGene00001701          grd-12  locomotion variant  WBPhenotype:0000643
# 756   WBGene00001949           hlh-2  locomotion variant  WBPhenotype:0000643
# 785   WBGene00016170        tmem-131  locomotion variant  WBPhenotype:0000643
# 825   WBGene00000105           alg-1  locomotion variant  WBPhenotype:0000643
# 865   WBGene00018819           rog-1  locomotion variant  WBPhenotype:0000643
# 891   WBGene00018027         F35A5.5  locomotion variant  WBPhenotype:0000643
# 910   WBGene00017241          pcyt-1  locomotion variant  WBPhenotype:0000643
# 981   WBGene00013168           arp-1  locomotion variant  WBPhenotype:0000643
# 1034  WBGene00006382           taf-1  locomotion variant  WBPhenotype:0000643
# 1073  WBGene00003939           pax-3  locomotion variant  WBPhenotype:0000643
# 1115  WBGene00000161           apa-2  locomotion variant  WBPhenotype:0000643
# 1181  WBGene00000739         col-166  locomotion variant  WBPhenotype:0000643
# 1242  WBGene00004873           smc-3  locomotion variant  WBPhenotype:0000643
# 1446  WBGene00013343           prp-6  locomotion variant  WBPhenotype:0000643
# 1466  WBGene00006516          vps-16  locomotion variant  WBPhenotype:0000643
# 1482  WBGene00001885          his-11  locomotion variant  WBPhenotype:0000643
# ...              ...             ...                 ...                  ...
# 2984  WBGene00018699  WBGene00018699  locomotion variant  WBPhenotype:0000643
# 3025  WBGene00012704           mlt-3  locomotion variant  WBPhenotype:0000643
# 3045  WBGene00010204         F57F5.1  locomotion variant  WBPhenotype:0000643
# 3111  WBGene00007008           rfp-1  locomotion variant  WBPhenotype:0000643
# 3142  WBGene00003925           pas-4  locomotion variant  WBPhenotype:0000643
# 3185  WBGene00001328           epi-1  locomotion variant  WBPhenotype:0000643
# 3263  WBGene00000741         col-168  locomotion variant  WBPhenotype:0000643
# 3273  WBGene00004341           rfl-1  locomotion variant  WBPhenotype:0000643
# 3291  WBGene00004829           sli-1  locomotion variant  WBPhenotype:0000643
# 3297  WBGene00011758         T13H5.4  locomotion variant  WBPhenotype:0000643
# 3330  WBGene00010785           top-2  locomotion variant  WBPhenotype:0000643
# 3377  WBGene00012261           lpr-3  locomotion variant  WBPhenotype:0000643
# 3422  WBGene00001517           gar-1  locomotion variant  WBPhenotype:0000643
# 3428  WBGene00001087          dpy-28  locomotion variant  WBPhenotype:0000643
# 3540  WBGene00003952           pbs-6  locomotion variant  WBPhenotype:0000643
# 3606  WBGene00001876           his-2  locomotion variant  WBPhenotype:0000643
# 3660  WBGene00000218           asp-5  locomotion variant  WBPhenotype:0000643
# 3666  WBGene00008053        cdc-48.2  locomotion variant  WBPhenotype:0000643
# 3788  WBGene00001019           dnj-1  locomotion variant  WBPhenotype:0000643
# 3792  WBGene00018270         F41C3.4  locomotion variant  WBPhenotype:0000643
# 3806  WBGene00000931           dao-5  locomotion variant  WBPhenotype:0000643
# 3854  WBGene00004259           pyr-1  locomotion variant  WBPhenotype:0000643
# 3870  WBGene00001570          gei-13  locomotion variant  WBPhenotype:0000643
# 3964  WBGene00003639          nhr-49  locomotion variant  WBPhenotype:0000643
# 4124  WBGene00006584           tni-1  locomotion variant  WBPhenotype:0000643
# 4141  WBGene00006432  WBGene00006432  locomotion variant  WBPhenotype:0000643
# 4186  WBGene00006829         unc-101  locomotion variant  WBPhenotype:0000643
# 4204  WBGene00019154           glf-1  locomotion variant  WBPhenotype:0000643
# 4256  WBGene00302964      Y62E10A.23  locomotion variant  WBPhenotype:0000643
# 4271  WBGene00185088       Y55F3BL.4  locomotion variant  WBPhenotype:0000643
#
#                                            WB source ID
# 0     WBRNAi00025129|WBPaper00006395 WBRNAi00025631|...
# 57                       WBRNAi00024350|WBPaper00006395
# 118                      WBRNAi00026070|WBPaper00006395
# 168                      WBRNAi00075428|WBPaper00006132
# 185                      WBRNAi00024683|WBPaper00006395
# 227   WBRNAi00004607|WBPaper00004402 WBRNAi00026682|...
# 290   WBRNAi00008979|WBPaper00005654 WBRNAi00025934|...
# 356                      WBRNAi00078339|WBPaper00027214
# 394   WBRNAi00009019|WBPaper00005654 WBRNAi00026001|...
# 536   WBRNAi00026026|WBPaper00006395 WBRNAi00074594|...
# 566                      WBRNAi00075324|WBPaper00029258
# 604   WBRNAi00077019|WBPaper00026841 WBRNAi00077023|...
# 639                      WBRNAi00089729|WBPaper00040284
# 655   WBRNAi00075171|WBPaper00029258 WBRNAi00075173|...
# 707                      WBRNAi00077024|WBPaper00026841
# 756   WBRNAi00009007|WBPaper00005654 WBRNAi00077261|...
# 785   WBRNAi00008452|WBPaper00005654 WBRNAi00024656|...
# 825   WBRNAi00008819|WBPaper00005654 WBRNAi00025553|...
# 865                      WBRNAi00001045|WBPaper00004651
# 891                      WBRNAi00027318|WBPaper00006395
# 910   WBRNAi00025032|WBPaper00006395 WBRNAi00027260|...
# 981   WBRNAi00009379|WBPaper00005654 WBRNAi00026815|...
# 1034  WBRNAi00026477|WBPaper00006395 WBRNAi00026478|...
# 1073  WBRNAi00008706|WBPaper00005654 WBRNAi00025285|...
# 1115  WBRNAi00009191|WBPaper00005654 WBRNAi00026328|...
# 1181                     WBRNAi00026228|WBPaper00006395
# 1242                     WBRNAi00026718|WBPaper00006395
# 1446  WBRNAi00026881|WBPaper00006395 WBRNAi00037628|...
# 1466  WBRNAi00072897|WBPaper00029258 WBRNAi00072898|...
# 1482                     WBRNAi00025631|WBPaper00006395
# ...                                                 ...
# 2984                     WBRNAi00070598|WBPaper00004841
# 3025  WBRNAi00009314|WBPaper00005654 WBRNAi00026666|...
# 3045                     WBRNAi00025738|WBPaper00006395
# 3111  WBRNAi00026026|WBPaper00006395 WBRNAi00074594|...
# 3142                     WBRNAi00024749|WBPaper00006395
# 3185                     WBRNAi00008971|WBPaper00005654
# 3263                     WBRNAi00026228|WBPaper00006395
# 3273                     WBRNAi00027275|WBPaper00006395
# 3291                     WBRNAi00109167|WBPaper00046120
# 3297                     WBRNAi00075301|WBPaper00029258
# 3330                     WBRNAi00078335|WBPaper00027214
# 3377  WBRNAi00009253|WBPaper00005654 WBRNAi00026489|...
# 3422                     WBRNAi00075430|WBPaper00006132
# 3428                     WBRNAi00009310|WBPaper00005654
# 3540  WBRNAi00008327|WBPaper00005654 WBRNAi00024451|...
# 3606  WBRNAi00025512|WBPaper00006395 WBRNAi00026260|...
# 3660                     WBRNAi00078339|WBPaper00027214
# 3666  WBRNAi00024790|WBPaper00006395 WBRNAi00078676|...
# 3788                     WBRNAi00027137|WBPaper00006395
# 3792                     WBRNAi00008776|WBPaper00005654
# 3806  WBRNAi00024619|WBPaper00006395 WBRNAi00024620|...
# 3854                     WBRNAi00008581|WBPaper00005654
# 3870  WBRNAi00008892|WBPaper00005654 WBRNAi00025742|...
# 3964                     WBRNAi00025936|WBPaper00006395
# 4124  WBRNAi00025481|WBPaper00006395 WBRNAi00027336|...
# 4141  WBRNAi00025372|WBPaper00006395 WBRNAi00027316|...
# 4186  WBRNAi00025950|WBPaper00006395 WBRNAi00025951|...
# 4204  WBRNAi00008915|WBPaper00005654 WBRNAi00025787|...
# 4256                     WBRNAi00027543|WBPaper00006395
# 4271                     WBRNAi00009393|WBPaper00005654
#
# [100 rows x 5 columns]

# %% [markdown]
# ## use reference list to extract only protein coding genes

# %%
cElegans_proteinCoding = cElegans_geneInfo[cElegans_geneInfo["type_of_gene"] == "protein-coding"]

# %%
df_onlyProteinCoding = df.loc[df["WB gene ID"].isin(cElegans_proteinCoding["dbXrefs"].unique())]

# %%
df_onlyProteinCoding.shape
# Out:
# (53433, 5)

# %% [markdown]
# ## load the table for PMID # reference

# %%
paper_lookup = pd.read_csv('input/WB_paper_id_conversion_table', sep='~', header=None)
paper_lookup.columns = ['info']

# %%
paper_lookup.head()
# Out:
#                                          info
# 0                        WBPaper00000003 cgc3
# 1                        WBPaper00000005 cgc5
# 2  WBPaper00000005 doi10.1163/187529275X00518
# 3                        WBPaper00000006 cgc6
# 4                        WBPaper00000007 cgc7

# %%
## need to split the file and then create a dictionary for each paper id
table = paper_lookup['info'].apply(lambda x: x.split(' '))
table_dict = {}
for i in range(len(table)):
    table_dict[table[i][0]] = table[i][1]

# %%
table_dict['WBPaper00006395']
# Out:
# 'pmid14551910'

# %% [markdown]
# ## create gmt by writing to file

# %%
filename = 'wormbase_rnai_phenotype_%s.gmt'% str(datetime.date.today())[0:7].replace('-', '_')
file = open(filename,'w+') 
terms = df["phenotype"].unique()
for term in terms:
    df_byTerm = df_onlyProteinCoding.loc[df["phenotype"] == term].copy()
    
    if df_byTerm.shape[0] > 4:
        # convert gene name using the cElegans gene info table
        change_name = lambda x: cElegans_geneInfo.loc[cElegans_geneInfo["dbXrefs"] == x]["Symbol"].tolist()[0] if x in cElegans_geneInfo["dbXrefs"].values else x
        df_byTerm["Gene symbol"] = df_byTerm["WB gene ID"].apply(change_name)
        # split splice variant names. some genes have format X.#.# where the second decimal describes a TX ID
        split_splice = lambda x: (x.split('.')[0] + x.split('.')[1]) if len(x.split('.')) > 2 else x
        df_byTerm["Gene symbol"] = df_byTerm["Gene symbol"].apply(split_splice)
        
        if len(df_byTerm["Gene symbol"].unique()) > 4:
            file.write("%s" % term + "_" + df_byTerm.iloc[0, 3] + '\t')
            file.write("\t")
            genes = df_byTerm["Gene symbol"].unique()
            for gene in genes:
                file.write("%s\t" % gene)
            file.write("\n")
        
file.close()
