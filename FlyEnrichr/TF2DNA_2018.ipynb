# %% [markdown]
# # TF2DNA Transcription Factor Target Library

# %% [markdown]
# Author: Zachary Flamholz
# Date: 07-2018
# Database: http://fiserlab.org/tf2dna_db//index.html
# Data: http://fiserlab.org/tf2dna_db//downloads.html

# %%
import pandas as pd
import numpy as np
import glob
import sys
import datetime

# %% [markdown]
# # Versions of Modules in Use

# %%
# %load_ext version_information
# %version_information numpy, pandas
# Out:
# Software versions
# Python 3.6.5 64bit [GCC 4.2.1 Compatible Apple LLVM 9.1.0 (clang-902.0.39.1)]
# IPython 6.4.0
# OS Darwin 17.5.0 x86_64 i386 64bit
# numpy 1.14.5
# pandas 0.23.1
# Wed Jul 18 13:03:00 2018 EDT

# %% [markdown]
# ## read in data, different experiments are different files

# %%
path = 'input/TF2DNA_fly/*'
folders = glob.glob(path)
names = []
dfs = []
for folder in folders:
    path2 = folder + '/*.pscan'
    files = glob.glob(path2)
    
    for file in files:
        
        dirs = file.split('/')

        desc = dirs[2].split('_')
        
        exper = dirs[3].split('.')
        
        ## the name has the form TF_PMID, this becomes the term name
        names.append(exper[0] + '_' + desc[3])
        
        dfs.append(pd.read_csv(file, sep='\t', header=0))

# %%
dfs[0].head()
# Out:
#   tf_name target_name  start_position  end_position direction  binding_score  \
# 0     bap      CG5895        16028334      16028634       (+)        1308.09
# 1     bap      CG8042         7968041       7968341       (-)        1155.31
# 2     bap      CG7536        17979445      17979745       (-)         849.76
# 3     bap      CG7220         6618589       6618889       (+)         747.91
# 4     bap        Mulk        10269800      10270100       (+)         798.83
#
#     p_value                                      binding_sites
# 0  0.000026                          16028340:1308.09:0.000026
# 1  0.000110                           7968118:1155.31:0.000110
# 2  0.000369  17979568:849.76:0.000369 17979680:722.44:0.000573
# 3  0.000515                            6618604:747.91:0.000515
# 4  0.000442                           10269942:798.83:0.000442

# %%
names[0]
# Out:
# 'bap_PMID-25215497'

# %%
for exper in dfs:
    print(len(exper))
# Out:
# 4866
# 5085
# 2424
# 3752
# 6459
# 6854
# 6094
# 3515
# 6907
# 2662
# 6823
# 5684
# 6411
# 2757
# 8349
# 11800
# 3750
# 3828
# 5541
# 9427
# 3052
# 3581
# 5744
# 2128
# 5559
# 3344
# 5135
# 8842
# 10769
# 7433
# 5168
# 6192
# 5184
# 4911
# 4246
# 5362
# 3153
# 2980
# 5330
# 4696
# 8853
# 4119
# 4110
# 5659
# 3243
# 5899
# 6394
# 5166
# 7742
# 3540
# 6375
# 2859
# 3884
# 5744
# 9269
# 6461
# 4098
# 782
# 3984
# 2932
# 5523
# 7614
# 5315
# 3034
# 6059
# 4774
# 6144
# 3392
# 6209
# 5127
# 4579
# 5070
# 3110
# 2979
# 4321
# 7273
# 4398
# 4971
# 7748
# 3134
# 3347
# 2878
# 4655
# 8295
# 4143
# 3590
# 3043
# 6349
# 7234
# 6339
# 2981
# 5699
# 5764
# 6108
# 7896
# 3557
# 6339
# 3822
# 6339
# 5764
# 7171
# 3258
# 5710
# 7836
# 5764
# 5565
# 4633
# 3707
# 3657
# 5340
# 3705
# 3702
# 4897
# 3654
# 3896
# 6339
# 4401
# 5037
# 3884
# 6051
# 5271
# 6287
# 6520
# 1451
# 2967
# 10515
# 2355
# 4718
# 3334
# 4083
# 7326
# 5434
# 219
# 5864
# 5225
# 6035
# 4336
# 5074
# 7022
# 6554
# 4557
# 4633
# 2755
# 5178
# 4547
# 6843
# 782
# 6197
# 4492
# 5767
# 9564
# 6252
# 4671
# 5033
# 5504
# 5561
# 8047
# 2968
# 5290
# 3691
# 5831
# 7614
# 6127
# 6166
# 5059
# 6207
# 3967
# 3031
# 7634
# 3982
# 5530
# 3590
# 3514
# 3183
# 3954
# 8156
# 5376
# 3124
# 7447
# 8288
# 2646
# 4299
# 4989
# 3188
# 4121
# 5069
# 5188
# 6629
# 5037
# 7086
# 6996
# 5144
# 4082
# 4157
# 11178
# 3104
# 4005
# 4125
# 6353
# 4924
# 4074
# 6461
# 9093
# 4458
# 5804
# 6521
# 5188
# 6578
# 5804
# 6038
# 6658
# 4155
# 5297
# 5200
# 6600
# 3496
# 4432
# 6780
# 4332
# 4869
# 6566
# 7481
# 6843
# 2947
# 10886
# 4311
# 5376
# 5720
# 6580
# 5699
# 4673
# 4853
# 6140
# 2748
# 6848
# 3913
# 3878
# 6599
# 5108
# 6019
# 3255
# 5017
# 5849
# 5930
# 5603
# 10230
# 4505
# 3226
# 6196
# 6093
# 8921
# 5883
# 6059
# 10263
# 4078
# 3050
# 5195
# 4110
# 3595
# 5030
# 5289
# 4988
# 5224
# 4589
# 3926
# 2989
# 6656
# 7348
# 4958
# 6181
# 5002
# 4386
# 6188
# 5996
# 7091
# 3116
# 3278
# 4142
# 3327
# 3410
# 7933
# 7441
# 6613
# 6845
# 3688
# 4907
# 6093
# 4296
# 3029
# 7446
# 6609
# 4224
# 11891
# 2366
# 10154
# 3727
# 6376
# 4487
# 5290
# 4560
# 6220
# 5562
# 5133
# 3974
# 4471
# 7408
# 5151
# 6565
# 4624
# 3563
# 5179
# 6355
# 9044
# 3755
# 4032
# 842
# 8316
# 4853
# 4316
# 10265
# 5836
# 7096
# 5957
# 7013
# 2095
# 7580
# 7200
# 7387
# 2213
# 6924
# 3529
# 5696
# 6536
# 3098
# 7485
# 4267
# 4649
# 5859
# 5737
# 7529
# 7600
# 5172
# 6199
# 6976
# 0
# 1908
# 7598
# 6680
# 5860
# 0
# 4781
# 5172
# 6144
# 3933
# 5529
# 5040
# 6520
# 3449
# 6661
# 5518
# 4417
# 0
# 5767
# 5793
# 9567
# 7240
# 3691
# 5416
# 6432
# 7142
# 6550
# 7200
# 7266
# 6371
# 1726
# 6783
# 3866
# 8184
# 3489
# 4258
# 7476
# 6232
# 0
# 4285
# 5872
# 7349
# 4458
# 4155
# 6600
# 4339
# 5128
# 5512
# 6441
# 7629
# 5703
# 5720
# 6897
# 3460
# 6432
# 8218
# 4943
# 5299
# 6259
# 5734
# 10230
# 2550
# 2709
# 7727
# 6394
# 8921
# 6330
# 6004
# 9044
# 4553
# 4988
# 6326
# 6986
# 5406
# 6250
# 7747
# 3175
# 7204
# 8384
# 7478
# 7286
# 5951
# 4262
# 4149
# 6811
# 5912

# %%
np.sort(np.array(dfs[1]['p_value']))[2000]
# Out:
# 0.000367

# %% [markdown]
# ## write gmt file from data

# %%
## writing gmt files
filename = 'TF2DNA_fly_%s.gmt'% str(datetime.date.today())[0:7].replace('-', '_')
file = open(filename,'w+')
lengths = []
lengths_kept = []
for i,exper in enumerate(dfs):
    
    if len(exper) > 2000:
        val = np.sort(np.array(exper['p_value']))[2000]
        test = exper[exper['p_value'] < val]

        ## sometimes a lot of targets have the same binding score so the number of genes gets very low
        if (len(test) < 100):
            exper = exper[exper['p_value'] < val + .00001]
        else:
            exper = test
            
    lengths.append(len(exper))
    
    ## discard experiments with too many or too few targets
    if len(exper) > 2999:
        continue
        
    if len(exper) < 5:
        continue
    
    lengths_kept.append(len(exper))
    file.write("%s" % names[i] + '\t')
    file.write("\t")
    genes = exper['target_name'].unique()
    for gene in genes:
        file.write("%s\t" % gene)
    file.write("\n")

file.close()

# %%
lengths = np.array(lengths)
lengths_kept = np.array(lengths_kept)

# %%
lengths.max()
# Out:
# 5058

# %%
lengths_kept.max()
# Out:
# 2918

# %%
len(lengths) - len(lengths_kept)
# Out:
# 8
